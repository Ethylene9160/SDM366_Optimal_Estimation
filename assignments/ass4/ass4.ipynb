# %%
import ls
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Question 1
# Here we're going to calculate theta. Below shows the H, theta and the square error.

# %%
theta = ls.q1()
# Out:
# H: [[1.    0.01  0.001]
#  [1.    0.04  0.008]
#  [1.    0.09  0.027]
#  [1.    0.16  0.064]
#  [1.    0.25  0.125]
#  [1.    0.36  0.216]
#  [1.    0.49  0.343]
#  [1.    0.64  0.512]
#  [1.    0.81  0.729]
#  [1.    1.    1.   ]]
# theta:  [-0.01956271  3.9854878  -2.46637583]
# error: 1.005479054367308

# %% [markdown]
# Use that theta we obtained, let's see the result of fitting the 100 points.

# %%
ls.q1_advance(theta)

# %% [markdown]
# # Question 2
# Notice that, the calculated results, contain very small complex parts, which might be caused by the calculation of float, so I use the `np.real` to get the real part of the result.
# Accorging to the question, here $\hat{y}$ represents the predicted value of $x$.

# %%
H, x, x_hat = ls.q2()
# Out:
# (31,)

# %% [markdown]
# ## Compare results with scipy.fft

# %%
ls.q2_compare(H, x, x_hat)
# Out:
# ======== My Results ========
# H:  [[ 0.03225806+0.j          0.03225806+0.j          0.03225806+0.j
#    0.03225806+0.j          0.03225806+0.j          0.03225806+0.j
#    0.03225806+0.j          0.03225806+0.j          0.03225806+0.j
#    0.03225806+0.j          0.03225806+0.j          0.03225806+0.j
#    0.03225806+0.j          0.03225806+0.j          0.03225806+0.j
#    0.03225806+0.j          0.03225806+0.j          0.03225806+0.j
#    0.03225806+0.j          0.03225806+0.j          0.03225806+0.j
#    0.03225806+0.j          0.03225806+0.j          0.03225806+0.j
#    0.03225806+0.j          0.03225806+0.j          0.03225806+0.j
#    0.03225806+0.j          0.03225806+0.j          0.03225806+0.j
#    0.03225806+0.j        ]
#  [ 0.03225806+0.j          0.03159774+0.0064935j   0.0296438 +0.01272116j
#    0.02647624+0.01842801j  0.02222474+0.02338041j  0.01706336+0.02737562j
#    0.0112034 +0.03025007j  0.00488477+0.03188607j -0.00163384+0.03221666j
# ...

# %% [markdown]
# Details, check https://github.com/Ethylene9160/SDM366_Optimal_Estimation for update.

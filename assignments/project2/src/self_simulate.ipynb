# %%
import numpy as np
import tools.pendulum as tpn
import tools.animation as tan

# %%
x0 = np.array([[0],[0.1],[0],[0]])

Q=np.eye(4)
R=np.eye(1)
print('shape of R: ', R)
pendulum = tpn.Pendulum(x=x0)
# Out:
# shape of R:  [[1.]]
# shape of A:  (4, 4)
# shape of B:  (4, 1)
# shape of Q:  (4, 4)
# shape of R:  (1, 1)
# SHAPE of K:  (1, 4)

# %%
T = 0.0001
steps = 8000
pendulum.init_state(x=x0)
for _ in range(steps):
    pendulum.step_in()
zs, thetas = pendulum.get_history()

# %%
tan.plot_robot_arm_dynamics(0,zs, thetas, 0.5,0.5,50)
